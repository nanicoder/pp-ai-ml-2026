# %% [markdown]
# <a href="https://colab.research.google.com/github/nanicoder/pp-ai-ml-2026/blob/main/ai-ml-simplilearn/classes/feb222026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df_binarycsv = pd.dataframe(ai-ml-simplilearn/data-sets/binary.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5951/4281706037.py in <cell line: 0>()
# ----> 1 df_binarycsv = pd.dataframe(ai-ml-simplilearn/data-sets/binary.csv)
#
# NameError: name 'pd' is not defined
